# %%
import requests, json

# %%
line_url = "https://guest.api.arcadia.pinnacle.com/0.1/sports/4/markets/straight?primaryOnly=false&withSpecials=false"
matchup_url = "https://guest.api.arcadia.pinnacle.com/0.1/sports/4/matchups?withSpecials=false"

headers = {
    "authority": "guest.api.arcadia.pinnacle.com",
    "x-api-key": "CmX2KcMrXuFmNg6YFbmTxE0y9CIrOi0R"
}

line_resp = requests.get(url = line_url, headers = headers)
matchup_resp = requests.get(url = matchup_url, headers = headers)

line_data = line_resp.json()
matchup_data = matchup_resp.json()

# %%
matchup_data
# Out:
# [{'ageLimit': 0,
#   'altTeaser': False,
#   'external': {},
#   'hasAltSpread': True,
#   'hasAltTotal': True,
#   'hasLive': False,
#   'hasMarkets': True,
#   'id': 1427406594,
#   'isBetshareEnabled': False,
#   'isHighlighted': False,
#   'isLive': False,
#   'isPromoted': False,
#   'league': {'ageLimit': 0,
#    'external': {},
#    'featureOrder': -1,
#    'group': 'Lithuania',
#    'id': 208618,
#    'isFeatured': False,
#    'isHidden': False,
#    'isPromoted': False,
#    'isSticky': False,
#    'matchupCount': 6,
#    'matchupCountSE': 6,
#    'name': 'Lithuania - National Basketball League',
#    'sport': {'featureOrder': 4,
#     'id': 4,
#     'isFeatured': True,
#     'isHidden': False,
#     'isSticky': False,
#     'matchupCount': 136,
#     'matchupCountSE': 124,
#     'name': 'Basketball',
#     'primaryMarketType': 'spread'}},
#   'liveMode': None,
#   'parent': None,
#   'parentId': None,
#   'parlayRestriction': 'unique_matchups',
# ...
